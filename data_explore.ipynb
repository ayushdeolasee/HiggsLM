# %%
import json
import os
import pathlib

# %%
check = [13828, 5766, 481, 749, 1884, 2728, 257, 1048, 284, 1205, 257, 17372, 30]

with open("./data/eval/1.json", "r") as f:
    print(json.loads(f.read()))
# Out:
# [{'question': [13828, 5766, 481, 749, 1884, 2728, 257, 1048, 284, 1205, 257, 17372, 30], 'answer': 1, 'options': [[64, 1232, 8280, 28175, 706, 5517], [64, 23462, 3265, 287, 262, 46005], [28116, 282, 14416, 13166, 319, 262, 4168], [35684, 15782, 9700, 852, 3100, 7287, 287, 262, 11384]]}, {'question': [26656, 5135, 389, 5307, 16357, 20296, 925, 286, 4077, 33773, 290, 38467, 13, 1867, 466, 262, 4077, 33773, 5127, 284, 262, 38467, 287, 428, 5307, 16357, 2776, 30], 'answer': 1, 'options': [[29255, 17556], [19425], [42846], [7050]]}, {'question': [2215, 257, 5078, 318, 973, 287, 281, 12278, 10349, 11, 262, 5078, 460], 'answer': 3, 'options': [[25587, 262, 3877, 284, 1382, 13], [24988, 589, 290, 10070, 262, 15004, 13], [25587, 262, 1459, 284, 1487, 4571, 13], [11338, 290, 923, 262, 5202, 286, 1459, 13]]}, {'question': [13828, 286, 262, 1708, 318, 281, 1672, 286, 281, 3342, 425, 3335, 30], 'answer': 0, 'options': [[32057, 10317], [76, 20965, 13696], [3201, 31434], [1073, 5853, 1787]]}, {'que
# ...
